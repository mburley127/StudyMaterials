# %% [markdown]
# ### Remove Element (String/Array)
#
# Given an integer array `nums` and an integer `val`, remove all occurrences of `val` in `nums` in-place. The order of the elements may be changed. Then return the number of elements in `nums` which are not equal to `val`.
#
# Consider the number of elements in `nums` which are not equal to `val` to be `k`. To get accepted, you need to do the following things:
#
# - Change the array `nums` such that the first `k` elements of `nums` contain the elements which are not equal to `val`. The remaining elements of `nums` are not important, as well as the size of `nums`.
# - Return `k`.
#
# **Input**: `nums = [3,2,2,3]`, `val = 3`
# **Output**: `2`, `nums = [2,2,_,_]`

# %%
### Remove Element (String/Array)
class Solution(object):
    def removeElement(self, nums, val):
        """
        :type nums: List[int]
        :type val: int
        :rtype: int
        """
        # Pointer to track the position of valid elements
        k = 0
        # Iterate through the array
        for i in range(len(nums)):
            if nums[i] != val:
                # Place the valid element at index k
                nums[k] = nums[i]
                k += 1     
        # Return the count of elements not equal to val (k)
        return k  

# Test Cases
nums = [3, 2, 2, 3]
val = 3
solution = Solution()
k = solution.removeElement(nums, val)

# Test the function and print results
print("k:", k)                      # Output: 2
print("Modified nums:", nums[:k])   # Output: [2, 2]
# Out:
# k: 2
# Modified nums: [2, 2]

# %% [markdown]
# ### Majority Element (String/Array)
# Given an array `nums` of size `n`, return the majority element.
# The majority element is the element that appears more than ⌊n / 2⌋ times. You may assume that the majority element always exists in the array.
#
# #### Example 1:
# **Input**: `nums = [3,2,3]`
# **Output**: `3`
#
# #### Example 2:
# **Input**: `nums = [2,2,1,1,1,2,2]`
# **Output**: `2`

# %%
### Majority Element
class Solution(object):
    def majorityElement(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        # Dictionary to store counts
        counts = {}
        # Iterate over the nums array
        for num in nums:
            # If num is already in the counts dict, add it
            if num in counts:
                counts[num] += 1
            else:
                counts[num] = 1
        # Return the highest value index in the array
        max_key = max(counts, key = counts.get)
        return max_key

# Test cases
nums1 = [3, 2, 3]
nums2 = [2, 2, 1, 1, 1, 2, 2]

# Instantiate the solution
solution = Solution()

# Test the function and print results
print(solution.majorityElement(nums1))  # Expected output: 3
print(solution.majorityElement(nums2))  # Expected output: 2
# Out:
# 3
# 2

# %% [markdown]
# ### Remove Duplicates from Sorted Array
#
# Given an integer array `nums` sorted in non-decreasing order, remove the duplicates **in-place** such that each unique element appears only once. The relative order of the elements should be kept the same. Then return the number of unique elements in `nums`.
#
# Consider the number of unique elements in `nums` to be `k`. To get accepted, you need to do the following things:
#
# - Change the array `nums` such that the first `k` elements of `nums` contain the unique elements in the order they were present in `nums` initially. The remaining elements of `nums` are not important, as well as the size of `nums`.
# - Return `k`.
#
# **Input**: `nums = [1,1,2]`
# **Output**: `2`, `nums = [1,2,_]`

# %%
### Remove Duplicates from Sorted Array
class Solution(object):
    def removeDuplicates(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        # Initialize two pointers
        k = 0  # Pointer to track the position of unique elements

        # Iterate through the array with pointer j
        for j in range(1, len(nums)):
            # If the current element is different from the last unique element
            if nums[j] != nums[k]:
                k += 1  # Move k to the next position
                nums[k] = nums[j]  # Update nums[k] with the new unique element

        # Return the number of unique elements
        return k + 1  # +1 because k is index-based
    
# Test cases
nums1 = [1, 1, 2]
nums2 = [0, 0, 1, 1, 1, 2, 2, 3, 3, 4]

solution = Solution()

print(solution.removeDuplicates(nums1))  # Output: 2
print(nums1[:2])  # Output: [1, 2]

print(solution.removeDuplicates(nums2))  # Output: 5
print(nums2[:5])  # Output: [0, 1, 2, 3, 4]
# Out:
# 2
# [1, 2]
# 5
# [0, 1, 2, 3, 4]

# %% [markdown]
# ### Best Time to Buy and Sell Stock
#
# You are given an array `prices` where `prices[i]` is the price of a given stock on the `i`th day.
#
# You want to **maximize your profit** by choosing a **single day to buy one stock** and choosing a **different day in the future** to sell that stock.
#
# Return the **maximum profit** you can achieve from this transaction. If you cannot achieve any profit, return `0`.

# %%
### Best Time to Buy a Stock
class Solution(object):
    def maxProfit(self, prices):
        """
        :type prices: List[int]
        :rtype: int
        """
        buy = float('inf')  # Initialize buy price as infinity
        max_profit = 0  # Start with zero profit

        for price in prices:
            # Update the minimum buy price
            if price < buy:
                buy = price
            # Calculate profit if sold at current price
            elif price - buy > max_profit:
                max_profit = price - buy  # Update max profit

        return max_profit

# Test Cases
prices1 = [7, 1, 5, 3, 6, 4]
prices2 = [4, 3, 5, 1, 9]
prices3 = [7, 6, 4, 3, 1]  # No profit case

solution = Solution()
print(solution.maxProfit(prices1))  # Expected output: 5
print(solution.maxProfit(prices2))  # Expected output: 8
print(solution.maxProfit(prices3))  # Expected output: 0
# Out:
# 5
# 8
# 0

# %% [markdown]
# ### Roman to Integer
# #### Roman numerals are represented by seven different symbols:
#
# | Symbol | Value |
# |--------|-------|
# | I      | 1     |
# | V      | 5     |
# | X      | 10    |
# | L      | 50    |
# | C      | 100   |
# | D      | 500   |
# | M      | 1000  |
#
# - **Basic Addition**:
#   - `II = 1 + 1 = 2`
#   - `XII = 10 + 2 = 12`
#   - `XXVII = 20 + 5 + 2 = 27`
#
# - **Subtraction Rule**:
#   Roman numerals are usually written **largest to smallest** from left to right.
#   However, there are cases where **subtraction** is used:
#   - `IV = 4` (since `I` comes before `V`, subtract `1`)
#   - `IX = 9` (since `I` comes before `X`, subtract `1`)
#
#   **Instances where subtraction is used:**
#   - `I` can be placed before `V (5)` and `X (10)` → **4 and 9**
#   - `X` can be placed before `L (50)` and `C (100)` → **40 and 90**
#   - `C` can be placed before `D (500)` and `M (1000)` → **400 and 900**
#
# Given a **Roman numeral**, convert it to an **integer**.

# %%
### Roman to Integer
class Solution(object):
    def romanToInt(self, s):
        """
        :type s: str
        :rtype: int
        """
        # Dictionary to Store Roman Numerals
        roman_values = {
            'I': 1, 'V': 5, 'X': 10, 'L': 50,
            'C': 100, 'D': 500, 'M': 1000
        }
        # Store total and the previous value
        total = 0
        prev_value = 0 
        # Iterate over the string **from right to left**
        for char in reversed(s):
            current_value = roman_values[char]  # Look up the value from the dictionary
            # If the current value is smaller than prev_value, subtract it from total
            if current_value < prev_value:
                total -= current_value  # Subtract if a smaller numeral appears before a larger one
            else:
                total += current_value  # Otherwise, add the value
            # Update prev_value for the next iteration
            prev_value = current_value  

        return total

# Test Cases
s1 = 'III'
s2 = 'MCMXCIV'

solution = Solution()
print(solution.romanToInt(s1))  # Expected output: 3
print(solution.romanToInt(s2))  # Expected output: 1994
# Out:
# 3
# 1994

# %% [markdown]
# ### Length of Last Word
#
# Given a string `s` consisting of words and spaces, return the **length of the last word** in the string.
#
# A **word** is defined as a maximal sequence of **non-space characters**.
#
# #### **Example 1**
# **Input**: `s = "Hello World"`
# **Output**: `5`
# **Explanation**: The last word is `"World"` with length **5**.
#
# #### **Example 2**
# **Input**: `s = "   fly me   to   the moon  "`
# **Output**: `4`
# **Explanation**: The last word is `"moon"` with length **4**.

# %%
### Length of Last Word
class Solution(object):
    def lengthOfLastWord(self, s):
        """
        :type s: str
        :rtype: int
        """
        # Initialize counter for the last word's length
        count = 0
        # Flag to start counting only when we hit a non-space character
        found_char = False
        # Iterate over the string from the end to the beginning
        for i in range(len(s) - 1, -1, -1):  # range(start, stop, step)
            if s[i] != ' ':
                count += 1
                found_char = True
            elif found_char:
                # If there is already found a word and hit a space, break
                break

        return count

# Test Cases
s1 = 'Hello World'
s2 = ' fly me to the moon '

solution = Solution()
print(solution.lengthOfLastWord(s1))  # Expected output: 5
print(solution.lengthOfLastWord(s2))  # Expected output: 4
# Out:
# 5
# 4
