# %% [markdown]
# ### 27. Remove Element (String/Array)
#
# Given an integer array `nums` and an integer `val`, remove all occurrences of `val` in `nums` in-place. The order of the elements may be changed. Then return the number of elements in `nums` which are not equal to `val`.
#
# Consider the number of elements in `nums` which are not equal to `val` to be `k`. To get accepted, you need to do the following things:
#
# - Change the array `nums` such that the first `k` elements of `nums` contain the elements which are not equal to `val`. The remaining elements of `nums` are not important, as well as the size of `nums`.
# - Return `k`.
#
# **Input**: `nums = [3,2,2,3]`, `val = 3`
# **Output**: `2`, `nums = [2,2,_,_]`

# %%
### Remove Element (String/Array)
class Solution(object):
    def removeElement(self, nums, val):
        """
        :type nums: List[int]
        :type val: int
        :rtype: int
        """
        # Pointer to track the position of valid elements
        k = 0
        # Iterate through the array
        for i in range(len(nums)):
            if nums[i] != val:
                # Place the valid element at index k
                nums[k] = nums[i]
                k += 1     
        # Return the count of elements not equal to val (k)
        return k  

# Test Cases
nums = [3, 2, 2, 3]
val = 3
solution = Solution()
k = solution.removeElement(nums, val)

# Test the function and print results
print("k:", k)                      # Output: 2
print("Modified nums:", nums[:k])   # Output: [2, 2]
# Out:
# k: 2
# Modified nums: [2, 2]

# %% [markdown]
# ### 26. Remove Duplicates from Sorted Array
#
# Given an integer array `nums` sorted in non-decreasing order, remove the duplicates **in-place** such that each unique element appears only once. The relative order of the elements should be kept the same. Then return the number of unique elements in `nums`.
#
# Consider the number of unique elements in `nums` to be `k`. To get accepted, you need to do the following things:
#
# - Change the array `nums` such that the first `k` elements of `nums` contain the unique elements in the order they were present in `nums` initially. The remaining elements of `nums` are not important, as well as the size of `nums`.
# - Return `k`.
#
# **Input**: `nums = [1,1,2]`
# **Output**: `2`, `nums = [1,2,_]`

# %%
### Remove Duplicates from Sorted Array
class Solution(object):
    def removeDuplicates(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        # Initialize two pointers
        k = 0  # Pointer to track the position of unique elements

        # Iterate through the array with pointer j
        for j in range(1, len(nums)):
            # If the current element is different from the last unique element
            if nums[j] != nums[k]:
                k += 1  # Move k to the next position
                nums[k] = nums[j]  # Update nums[k] with the new unique element

        # Return the number of unique elements
        return k + 1  # +1 because k is index-based
    
# Test cases
nums1 = [1, 1, 2]
nums2 = [0, 0, 1, 1, 1, 2, 2, 3, 3, 4]

solution = Solution()

print(solution.removeDuplicates(nums1))  # Output: 2
print(nums1[:2])  # Output: [1, 2]

print(solution.removeDuplicates(nums2))  # Output: 5
print(nums2[:5])  # Output: [0, 1, 2, 3, 4]
# Out:
# 2
# [1, 2]
# 5
# [0, 1, 2, 3, 4]

# %% [markdown]
# ### 121. Best Time to Buy and Sell Stock
#
# You are given an array `prices` where `prices[i]` is the price of a given stock on the `i`th day.
#
# You want to **maximize your profit** by choosing a **single day to buy one stock** and choosing a **different day in the future** to sell that stock.
#
# Return the **maximum profit** you can achieve from this transaction. If you cannot achieve any profit, return `0`.

# %%
### Best Time to Buy a Stock
class Solution(object):
    def maxProfit(self, prices):
        """
        :type prices: List[int]
        :rtype: int
        """
        buy = float('inf')  # Initialize buy price as infinity
        max_profit = 0  # Start with zero profit

        for price in prices:
            # Update the minimum buy price
            if price < buy:
                buy = price
            # Calculate profit if sold at current price
            elif price - buy > max_profit:
                max_profit = price - buy  # Update max profit

        return max_profit

# Test Cases
prices1 = [7, 1, 5, 3, 6, 4]
prices2 = [4, 3, 5, 1, 9]
prices3 = [7, 6, 4, 3, 1]  # No profit case

solution = Solution()
print(solution.maxProfit(prices1))  # Expected output: 5
print(solution.maxProfit(prices2))  # Expected output: 8
print(solution.maxProfit(prices3))  # Expected output: 0
# Out:
# 5
# 8
# 0

# %% [markdown]
# ## 217. Contains Duplicates
#
# **Problem:**
# Given an integer array `nums`, return `true` if any value appears **at least twice** in the array, and return `false` if every element is **distinct**.

# %%
# Contains Duplicates
class Solution(object):
    def containsDuplicate(self, nums):
        """
        :type nums: List[int]
        :rtype: bool
        """
        list = []
        for num in nums:
            # if num is in tracker list, return true
            if num in list:
                return True
            else:
                # else we add the number
                list.append(num)
        # After iteration is complete, if True not returned then return false
        return False

# Test Cases
nums = [7, 1, 5, 3, 6, 3]

solution = Solution()
print(solution.containsDuplicate(nums))  # Expected output: 5
# Out:
# True

# %% [markdown]
# ### 268. Missing Number
#
# **Problem:**
# Given an array `nums` containing `n` distinct numbers in the range `[0, n]`, return the only number in the range that is missing from the array.

# %%
### Missing Number
class Solution(object):
    def missingNumber(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        # Convert list to set to remove duplicate elements
        my_set = set(nums)
        # Iterate over the size of the list + 1 (If we iterate only to n, miss checking for n as a possible missing number)
        # If list = [0, 1, 3, 2] -> Need to loop to n+1 to return 4
        for i in range(len(nums) + 1):
            # Check if number is in the set, if not return it
            if i not in my_set:
                return i
        
# Test Cases
nums = [0, 3, 2, 4, 1, 6]

solution = Solution()
print(solution.missingNumber(nums))  # Expected output: 5
# Out:
# 5

# %% [markdown]
# ### 283. Move Zeroes
#
# **Problem**
# Given an integer array `nums`, move all `0`'s to the end of it while maintaining the relative order of the non-zero elements.
#
# **Note:**
# You must do this *in-place* without making a copy of the array.

# %%
### Move Zeros
class Solution(object):
    def moveZeros(self, nums):
        """
        :type nums: List[int]
        :rtype: None. Do not return anything, modify nums in-place instead.
        """
        j = 0  
        # First loop places nonzeros at the beginning of the array
        for i in range(len(nums)):
            if nums[i] != 0:
                nums[j] = nums[i]
                j += 1
        # Fill rest of the list with 0s
        for i in range(j, len(nums)):
            nums[i] = 0

# Test Case
nums = [0, 2, 5, 0, 3, 0]
solution = Solution()
solution.moveZeros(nums)
print(nums)  # Output: [2, 5, 3, 0, 0, 0]
# Out:
# [2, 5, 3, 0, 0, 0]

# %% [markdown]
# ## 349. Intersection of Two Arrays
#
# **Problem:**
# Given two integer arrays `nums1` and `nums2`, return an array of their intersection. Each element in the result must be **unique**, and you may return the result in **any order**.

# %%
# Intersection of Two Arrays
class Solution(object):
    def intersection(self, nums1, nums2):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :rtype: List[int]
        """
        result = []

        for i in nums1:
            # Check if the element exists in nums2 and is not already in the result
            if i in nums2 and i not in result:
                result.append(i)

        return result
    
# Test Cases
list1 = [1, 2, 4, 6, 7]
list2 = [2, 9, 11, 17, 3]

solution = Solution()
print(solution.intersection(list1, list2))  # Expected output: [2]
# Out:
# [2]
